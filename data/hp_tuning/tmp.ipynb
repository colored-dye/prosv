# %%
import pandas as pd

# df = pd.read_parquet('../concept500/prod_9b_l20_v1/generate/train_data.parquet')
df = pd.read_parquet('../concept500_contrast/prod_9b_l20_v1/generate/contrast_train_data.parquet')
df
# Out:
#                                           negative_input  \
# 0      Write an algorithm to implement a trie data st...
# 1      Design a Python code snippet that deletes all ...
# 2      Create a Python program that sends a request t...
# 3      What are the benefits of using classes instead...
# 4      Create a data structure in Python to represent...
# ...                                                  ...
# 35995       What is the team that Michael Jordan played?
# 35996                                  What is one year?
# 35997  What happens when you bring flammable objects ...
# 35998         Can you explain the Keto diet and ketosis?
# 35999                               Who is Santa Clause?
#
#                                          negative_output  \
# 0      To implement a trie data structure, start by d...
# 1      numbers = [1, 2, 2, 3, 4, 4, 5]\nunique_number...
# 2      import requests\n\ndef fetch_website_content(u...
# ...

# %%
hp_set = [3, 2, 7]
subset = df[[True if i in hp_set else False for i in df['concept_id']]]
subset
# Out:
#                                         negative_input  \
# 144  What colors are typically associated with Chri...
# 145  Where was the 2017 European Judo Championships...
# 146       Where does the word plumbing originate from?
# 147                  What is America's oldest brewery?
# 148                What are the colors of the rainbow?
# ..                                                 ...
# 571                                    What is an API?
# 572  When was the last financial crisis and what ca...
# 573                Who became king of Holland in 1806?
# 574       What is the team that Michael Jordan played?
# 575  What gear do you need to go on a backpacking t...
#
#                                        negative_output  \
# 144  The colors typically associated with Christmas...
# 145  The 2017 European Judo Championships were held...
# 146  The word "plumbing" originates from the Latin ...
# 147  America's oldest brewery is Yuengling, which w...
# ...

# %%
subset['concept_id'] = subset['concept_id'].replace([3, 2, 7], [0,1,2])
# Out:
# /tmp/ipykernel_2758056/3229997307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['concept_id'] = subset['concept_id'].replace([3, 2, 7], [0,1,2])

# %%
# subset.to_parquet('train_data.parquet', index=False)
subset.to_parquet('contrast_train_data.parquet', index=False)

# %%
import pandas as pd

# df = pd.read_parquet('train_data.parquet')
df = pd.read_parquet('contrast_train_data.parquet')
df
# Out:
#                                         negative_input  \
# 0    What colors are typically associated with Chri...
# 1    Where was the 2017 European Judo Championships...
# 2         Where does the word plumbing originate from?
# 3                    What is America's oldest brewery?
# 4                  What are the colors of the rainbow?
# ..                                                 ...
# 211                                    What is an API?
# 212  When was the last financial crisis and what ca...
# 213                Who became king of Holland in 1806?
# 214       What is the team that Michael Jordan played?
# 215  What gear do you need to go on a backpacking t...
#
#                                        negative_output  \
# 0    The colors typically associated with Christmas...
# 1    The 2017 European Judo Championships were held...
# 2    The word "plumbing" originates from the Latin ...
# 3    America's oldest brewery is Yuengling, which w...
# ...
